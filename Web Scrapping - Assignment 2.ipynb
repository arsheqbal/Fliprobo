# %%
import selenium
import pandas as pd
import time

from selenium import webdriver

# %%
# activating the chrome browser
driver = webdriver.Chrome(r"C:\Users\Arsh\Desktop\Data Analysis\chromedriver.exe")

# %% [markdown]
# # Write a python program to scrape data for “Data Analyst” Job position in “Bangalore” location. You have to scrape the job-title, job-location, company_name, experience_required. You have to scrape first 10 jobs data.

# %%
# opening the homepage of naukri.com
driver.get('https://www.naukri.com')

# %%
# passing post name
search_inp = input('Enter the post name: ')
search_bar = driver.find_element_by_xpath("//div[@class='inpWrap']/input")
search_bar.clear()
search_bar.send_keys(search_inp)

# passing location
loc_inp = input('Enter location: ')
loc_bar = driver.find_element_by_id('qsb-location-sugg')
loc_bar.clear()
loc_bar.send_keys(loc_inp)
time.sleep(4)

# searching
search_btn = driver.find_element_by_xpath("//div[@class='search-btn']/button")
search_btn.click()
# Out:
# Enter the post name: Data Analyst
# Enter location: Bangalore

# %%
job_title = []
job_loc = []
comp_name = []
expr = []

# %%
# extracting job title
for i in driver.find_elements_by_xpath("//a[@class='title fw500 ellipsis']"):
    if len(job_title) == 10:
        break
    else:
        job_title.append(i.text)

# extracting job location
for j in driver.find_elements_by_xpath("//li[@class='fleft grey-text br2 placeHolderLi location']/span"):
    if len(job_loc) == 10:
        break
    else:
        job_loc.append(j.text)

# extracting company name
for k in driver.find_elements_by_xpath("//a[@class='subTitle ellipsis fleft']"):
    if len(comp_name) == 10:
        break
    else:
        comp_name.append(k.text)

# extracting experirncr required
for l in driver.find_elements_by_xpath("//li[@class='fleft grey-text br2 placeHolderLi experience']/span"):
    if len(expr) == 10:
        break
    else:
        expr.append(l.text)

# %%
print(len(job_title), len(job_loc), len(comp_name), len(expr))
# Out:
# 10 10 10 10

# %%
Jobs = pd.DataFrame({})
Jobs['title'] = job_title
Jobs['company'] = comp_name
Jobs['location'] = job_loc
Jobs['experience'] = expr

# %%
Jobs
# Out:
#                                                title  \
# 0    Data Scientist / Data Analyst -Business Analyst
# 1  Hiring Data Analysts For E commerce Platform |...
# 2                                       Data Analyst
# 3  Hiring For Data Analyst/ MIS Reporting Analyst...
# 4  DA - Urgent Opening For Data Analyst BFSI Doma...
# 5                     Data Analyst - Informatica MDM
# 6  Assistant Vice President - MIS & Reporting ( B...
# 7                                       Data Analyst
# 8                                       Data Analyst
# 9                                       Data Analyst
#
#                                              company  \
# 0                 Inflexion Analytix Private Limited
# 1                   Allegis Services India Pvt. Ltd.
# 2                                  Applied Materials
# 3   PHARMACEUTICAL RESEARCH ASSOCIATES INDIA Pvt Ltd
# 4                     Tata Consultancy Services Ltd.
# 5                Shell India Markets Private Limited
# 6  INTERTRUSTVITEOS CORPORATE AND FUND SERVICES P...
# 7                           Myntra Designs Pvt. Ltd.
# 8                           Myntra Designs Pvt. Ltd.
# 9                           Myntra Designs Pvt. Ltd.
#
#                                             location experience
# 0  Mumbai, Hyderabad/Secunderabad, Pune, Gurgaon/...    0-3 Yrs
# 1                                Bangalore/Bengaluru    0-5 Yrs
# 2                                Bangalore/Bengaluru   7-10 Yrs
# 3                                Bangalore/Bengaluru    2-4 Yrs
# 4  Kolkata, Hyderabad/Secunderabad, Pune, Ahmedab...    4-9 Yrs
# 5                                Bangalore/Bengaluru    6-9 Yrs
# 6                        Mumbai, Bangalore/Bengaluru  12-18 Yrs
# 7                                Bangalore/Bengaluru    3-6 Yrs
# 8                                Bangalore/Bengaluru    3-6 Yrs
# 9                                Bangalore/Bengaluru    4-9 Yrs

# %% [markdown]
# # Write a python program to scrape data for “Data Scientist” Job position in “Bangalore” location. You have to scrape the job-title, job-location, company_name, full job-description. You have to scrape first 10 jobs data.

# %%
# opening the homepage of naukri.com/
driver.get('https://www.naukri.com')

# %%
# passing post name
search_inp = input('Enter the post name: ')
search_bar = driver.find_element_by_xpath("//div[@class='inpWrap']/input")
search_bar.clear()
search_bar.send_keys(search_inp)

# passing location
loc_inp = input('Enter location: ')
loc_bar = driver.find_element_by_id('qsb-location-sugg')
loc_bar.clear()
loc_bar.send_keys(loc_inp)
time.sleep(4)

# searching
search_btn = driver.find_element_by_xpath("//div[@class='search-btn']/button")
search_btn.click()
# Out:
# Enter the post name: Data Scientist
# Enter location: Bangalore

# %%
job_title = []
job_loc = []
comp_name = []
desc = []
url = []

# %%
# extracting job title
for i in driver.find_elements_by_xpath("//a[@class='title fw500 ellipsis']"):
    if len(job_title) == 10:
        break
    else:
        job_title.append(i.text)

# extracting job location
for j in driver.find_elements_by_xpath("//li[@class='fleft grey-text br2 placeHolderLi location']/span"):
    if len(job_loc) == 10:
        break
    else:
        job_loc.append(j.text)

# extracting company name
for k in driver.find_elements_by_xpath("//a[@class='subTitle ellipsis fleft']"):
    if len(comp_name) == 10:
        break
    else:
        comp_name.append(k.text)

# storing url of description page
for l in driver.find_elements_by_xpath("//div[@class='info fleft']/a"):
    if len(url) == 10:
        break
    else:
        url.append(l.get_attribute('href'))

# extracting description required
for i in range(len(url)):
    page_url = url[i]
    driver.get(page_url)
    try:
        ele=driver.find_element_by_xpath("//div[@class='job-desc']")
        desc.append(ele.text)
    except NoSuchException as e:
        print("Exception Raised : ",e)
        ele=driver.find_element_by_xpath("//div[@class='clearboth description']")
        desc.append(ele.text)
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-7-dce8a6c92ff1> in <module>
#      30 for i in range(len(url)):
#      31     page_url = url[i]
# ---> 32     driver.get(page_url)
#      33     try:
#      34         ele=driver.find_element_by_xpath("//div[@class='job-desc']")
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in get(self, url)
#     331         Loads a web page in the current browser session.
#     332         """
# --> 333         self.execute(Command.GET, {'url': url})
#     334
#     335     @property
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# WebDriverException: Message: unknown error: net::ERR_INTERNET_DISCONNECTED
#   (Session info: chrome=90.0.4430.212)

# %%
desc

# %% [markdown]
# # Scraping data from naukri.com using filters

# %% [markdown]
# The location filter to be used is 'Delhi/NCR'

# %% [markdown]
# The salary filter to be used is '3-6' lakhs

# %%
driver.get('https://www.naukri.com')

# %%
# passing post name
search_inp = input('Enter the post name: ')
search_bar = driver.find_element_by_xpath("//div[@class='inpWrap']/input")
search_bar.clear()
search_bar.send_keys(search_inp)

# searching
search_btn = driver.find_element_by_xpath("//div[@class='search-btn']/button")
search_btn.click()
# Out:
# Enter the post name: Data Scientist

# %%
# getting location filters

loc_fltr = driver.find_element_by_xpath("//span[@title='Delhi / NCR']")
loc_fltr.click()

# %%
# getting salary filter
sal_fltr = driver.find_element_by_xpath("//span[@title='3-6 Lakhs']")
sal_fltr.click()

# %%
job_title = []
job_loc = []
comp_name = []
expr = []

# %%
# extracting job title
for i in driver.find_elements_by_xpath("//a[@class='title fw500 ellipsis']"):
    if len(job_title) == 10:
        break
    else:
        job_title.append(i.text)

# extracting job location
for j in driver.find_elements_by_xpath("//li[@class='fleft grey-text br2 placeHolderLi location']/span"):
    if len(job_loc) == 10:
        break
    else:
        job_loc.append(j.text)

# extracting company name
for k in driver.find_elements_by_xpath("//a[@class='subTitle ellipsis fleft']"):
    if len(comp_name) == 10:
        break
    else:
        comp_name.append(k.text)

# extracting experirncr required
for l in driver.find_elements_by_xpath("//li[@class='fleft grey-text br2 placeHolderLi experience']/span"):
    if len(expr) == 10:
        break
    else:
        expr.append(l.text)

# %%
jobs = pd.DataFrame({})
jobs['title'] = job_title
jobs['location'] = job_loc
jobs['company'] = comp_name
jobs['experience'] = expr
jobs
# Out:
#                                                title  \
# 0    Data Scientist / Data Analyst -Business Analyst
# 1  Data Scientist - High growth VC backed Influen...
# 2           Excellent opportunity For Data Scientist
# 3                                     Data Scientist
# 4           DATA Scientist – Gurgaon (Exp 3-6 years)
# 5           DATA Scientist – Gurgaon (Exp 3-6 years)
# 6                             Data Scientist - Noida
# 7                     Data Scientist - Noida/ B'lore
# 8                                     Data Scientist
# 9                                     Data Scientist
#
#                                             location  \
# 0  Mumbai, Hyderabad/Secunderabad, Pune, Gurgaon/...
# 1  Bangalore/Bengaluru, Delhi / NCR, Mumbai (All ...
# 2                         Noida, Bangalore/Bengaluru
# 3           New Delhi, Gurgaon/Gurugram, Delhi / NCR
# 4                      Gurgaon/Gurugram, Delhi / NCR
# 5                      Gurgaon/Gurugram, Delhi / NCR
# 6                                              Noida
# 7                         Noida, Bangalore/Bengaluru
# 8  Noida, Hyderabad/Secunderabad, Bangalore/Benga...
# 9  Bangalore/Bengaluru, Delhi / NCR, Mumbai (All ...
#
#                                              company experience
# 0                 Inflexion Analytix Private Limited    0-3 Yrs
# 1                    Ravgins International Pvt. Ltd.    3-5 Yrs
# 2              NEC CORPORATION INDIA PRIVATE LIMITED    3-7 Yrs
# 3                                           Mobikwik    3-5 Yrs
# 4  CRESCENDO GLOBAL LEADERSHIP HIRING INDIA PRIVA...    3-6 Yrs
# 5  CRESCENDO GLOBAL LEADERSHIP HIRING INDIA PRIVA...    3-6 Yrs
# 6     Optum Global Solutions (India) Private Limited    3-5 Yrs
# 7              NEC CORPORATION INDIA PRIVATE LIMITED    3-8 Yrs
# 8                             IBM India Pvt. Limited    4-9 Yrs
# 9           Cloudstrats Technologies Private Limited    5-8 Yrs

# %% [markdown]
# # Write a python program to scrape data for first 10 job results for Data scientist Designation in Noida location. You have to scrape company_name, No. of days ago when job was posted, Rating of the company.

# %%
driver.get('https://www.glassdoor.co.in/index.htm')

# %% [markdown]
# # Write a python program to scrape the salary data for Data Scientist designation in Noida location. You have to scrape Company name, Number of salaries, Average salary, Min salary, Max Salary.

# %% [markdown]
# # Scrape data of first 100 sunglasses listings on flipkart.com. You have to scrape four attributes: Brand, Product Description, Price, Discount.

# %%
driver.get('https://www.flipkart.com')

# %%
#closing login page
closing = driver.find_element_by_xpath("//button[@class='_2KpZ6l _2doB4z']")
closing.click()

# %%
# searching product

inp = input("Enter the product: ")
search = driver.find_element_by_xpath("//div[@class='_3OO5Xc']/input")
search.clear()
search.send_keys(inp)

search_btn = driver.find_element_by_xpath("//button[@class='L0Z3Pu']")
search_btn.click()
# Out:
# Enter the product: Sunglasses

# %%
brand = []
product_desc = []
price = []
discount = []
urls = []

# %%
url = driver.find_elements_by_xpath("//nav[@class='yFHi8N']/a")
for i in url:
    urls.append(i.get_attribute('href'))
for i in range(0,3):
    driver.get(urls[i])
    for m in driver.find_elements_by_xpath("//div[@class='_2WkVRV']"):
        if len(brand) == 100:
            break
        else:
            brand.append(m.text)
    
    for j in driver.find_elements_by_xpath("//div[@class='_30jeq3']"):
        if len(price) == 100:
            break
        else:
            price.append(j.text)
    
    for k in driver.find_elements_by_xpath("//div[@class='_3Ay6Sb']/span"):
        if len(discount) == 100:
            break
        else:
            discount.append(k.text)
    
    for l in driver.find_elements_by_xpath("//a[@class='IRpwTa']"):
        if len(desc) == 100:
            break
        else:
            desc.append(l.text)

# %%
sunglass = pd.DataFrame({})
sunglass['Brand'] = brand
sunglass['Description'] = desc
sunglass['Price'] = price
sunglass['Disscont'] = discount

# %%
sunglass
# Out:
#              Brand                                        Description   Price  \
# 0           AISLIN  UV Protection, Gradient Round, Shield Sunglass...    ₹395
# 1      like future  UV Protection, Polarized, Gradient, Mirrored W...    ₹284
# 2         Fastrack      UV Protection Wayfarer Sunglasses (Free Size)    ₹758
# 3         Fastrack   UV Protection Rectangular Sunglasses (Free Size)    ₹630
# 4       PHENOMENAL  UV Protection Retro Square Sunglasses (Free Size)    ₹399
# 5   ROZZETTA CRAFT  UV Protection Retro Square Sunglasses (Free Size)    ₹499
# 6         Fastrack       UV Protection Aviator Sunglasses (Free Size)    ₹674
# 7   ROZZETTA CRAFT  UV Protection, Gradient Rectangular Sunglasses...    ₹404
# 8         Fastrack      UV Protection Wayfarer Sunglasses (Free Size)    ₹733
# 9   ROZZETTA CRAFT  UV Protection, Riding Glasses Rectangular Sung...    ₹449
# 10        Fastrack  Gradient, UV Protection Wayfarer Sunglasses (F...    ₹621
# 11          PIRASO       UV Protection Aviator Sunglasses (Free Size)    ₹349
# 12          HIPPON             UV Protection Wayfarer Sunglasses (55)    ₹251
# 13       ROYAL SON         UV Protection Round Sunglasses (Free Size)    ₹664
# 14         DEIXELS         Others Retro Square Sunglasses (Free Size)    ₹209
# 15         Villain       UV Protection Aviator Sunglasses (Free Size)    ₹599
# 16    Singco India             UV Protection Wayfarer Sunglasses (56)    ₹339
# 17        Fastrack              UV Protection Aviator Sunglasses (54)    ₹759
# 18          PIRASO              UV Protection Cat-eye Sunglasses (60)    ₹250
# 19           NuVew      UV Protection Wayfarer Sunglasses (Free Size)    ₹419
# 20        Fastrack  UV Protection, Mirrored Retro Square Sunglasse...    ₹758
# 21      PHENOMENAL  UV Protection Aviator, Wayfarer Sunglasses (Fr...    ₹399
# 22         DEIXELS    UV Protection, Gradient Aviator Sunglasses (58)    ₹213
# 23          AISLIN              UV Protection Aviator Sunglasses (57)    ₹500
# 24          GANSTA              UV Protection Aviator Sunglasses (58)    ₹281
# 25        Fastrack              UV Protection Aviator Sunglasses (58)  ₹1,085
# 26           NuVew  UV Protection, Gradient Rectangular Sunglasses...    ₹215
# 27  ROZZETTA CRAFT  UV Protection, Gradient Round Sunglasses (Free...    ₹499
# 28  ROZZETTA CRAFT     UV Protection Shield, Wayfarer Sunglasses (61)    ₹426
# 29          AISLIN                   Mirrored Aviator Sunglasses (55)    ₹469
# ..             ...                                                ...     ...
# 70  ROZZETTA CRAFT  UV Protection, Mirrored, Gradient Wayfarer Sun...    ₹399
# 71        Badfella    UV Protection, Mirrored Cat-eye Sunglasses (68)    ₹269
# 72          GANSTA  Gradient, UV Protection Wayfarer Sunglasses (F...    ₹281
# 73           NuVew  UV Protection, Mirrored Retro Square Sunglasse...    ₹364
# 74        Fastrack  UV Protection, Night Vision, Gradient, Mirrore...    ₹682
# 75      PHENOMENAL  Mirrored, UV Protection Wayfarer Sunglasses (F...    ₹399
# 76            hipe              UV Protection Aviator Sunglasses (58)    ₹210
# 77        Fastrack         Others Retro Square Sunglasses (Free Size)    ₹777
# 78        Fastrack       UV Protection, Gradient Oval Sunglasses (58)  ₹1,115
# 79         Villain  UV Protection, Night Vision, Riding Glasses, G...    ₹599
# 80          AISLIN   UV Protection, Mirrored Wayfarer Sunglasses (53)    ₹525
# 81            hipe  UV Protection, Gradient Round, Shield Sunglass...    ₹210
# 82          GANSTA  Gradient, UV Protection Round Sunglasses (Free...    ₹224
# 83          AISLIN         UV Protection Retro Square Sunglasses (88)    ₹395
# 84            hipe              UV Protection Aviator Sunglasses (58)    ₹219
# 85       ROYAL SON   UV Protection, Gradient Wayfarer Sunglasses (53)    ₹569
# 86        Fastrack   UV Protection Rectangular Sunglasses (Free Size)  ₹1,148
# 87          GANSTA  UV Protection, Polarized, Gradient, Mirrored W...    ₹328
# 88         Ray-Ban                   Mirrored Aviator Sunglasses (55)  ₹3,019
# 89     like future      UV Protection Wayfarer Sunglasses (Free Size)    ₹284
# 90       ROYAL SON            Mirrored Aviator Sunglasses (Free Size)    ₹399
# 91        Fastrack         UV Protection Retro Square Sunglasses (88)    ₹576
# 92       ROYAL SON              UV Protection Aviator Sunglasses (60)    ₹399
# 93       ROYAL SON            Mirrored Aviator Sunglasses (Free Size)    ₹664
# 94       ROYAL SON  UV Protection Retro Square, Wayfarer Sunglasse...    ₹599
# 95      LIZA ANGEL         UV Protection Retro Square Sunglasses (58)     ₹49
# 96       Elligator  UV Protection Retro Square Sunglasses (Free Size)    ₹279
# 97           Wrogn  UV Protection Retro Square Sunglasses (Free Size)  ₹1,162
# 98        Fastrack              UV Protection Cat-eye Sunglasses (60)  ₹1,780
# 99           NuVew  UV Protection, Polarized Wayfarer Sunglasses (56)    ₹314
#
#    Disscont
# 0   77% off
# 1   71% off
# 2   15% off
# 3   21% off
# 4   80% off
# 5   77% off
# 6   25% off
# 7   79% off
# 8   18% off
# 9   79% off
# 10  22% off
# 11  78% off
# 12  79% off
# 13  66% off
# 14  73% off
# 15  20% off
# 16  71% off
# 17  15% off
# 18  84% off
# 19  71% off
# 20  15% off
# 21  80% off
# 22  82% off
# 23  69% off
# 24  85% off
# 25  16% off
# 26  72% off
# 27  77% off
# 28  84% off
# 29  74% off
# ..      ...
# 70  72% off
# 71  73% off
# 72  85% off
# 73  76% off
# 74  14% off
# 75  80% off
# 76  78% off
# 77  22% off
# 78  14% off
# 79  20% off
# 80  65% off
# 81  83% off
# 82  77% off
# 83  77% off
# 84  83% off
# 85  71% off
# 86  11% off
# 87  83% off
# 88  45% off
# 89  71% off
# 90  73% off
# 91  27% off
# 92  73% off
# 93  66% off
# 94  70% off
# 95  83% off
# 96  88% off
# 97  64% off
# 98  10% off
# 99  70% off
#
# [100 rows x 4 columns]

# %% [markdown]
# # Scrape 100 reviews data from flipkart.com for iphone11 phone.

# %%
driver.get('https://www.flipkart.com/apple-iphone-11-black-64-gb-includes-earpods-power-adapter/p/itm0f37c2240b217?pid=MOBFKCTSVZAXUHGR&lid=LSTMOBFKCTSVZAXUHGREPBFGI&marketplace.')

# %%
rating = []
r_sum = []
full_sum = []
urls1 = []

# %%
# opening the review page
clk = driver.find_element_by_xpath("//div[@class='_3UAT2v _16PBlm']/span")
clk.click()

# %%
url = driver.find_elements_by_xpath("//nav[@class='yFHi8N']/a")
for i in url:
    urls1.append(i.get_attribute('href'))
for i in range(0,10):
    driver.get(urls1[i])
    for i in driver.find_elements_by_xpath("//p[@class='_2-N8zT']"):
        rating.append(i.text)
    
    for j in driver.find_elements_by_xpath("//p[@class='_2-N8zT']"):
        r_sum.append(j.text)
    
    for k in driver.find_elements_by_xpath("//div[@class='t-ZTKy']"):
        full_sum.append(k.text)

# %%
iphone = pd.DataFrame({})
iphone['Rating'] = rating
iphone['Review Summary'] = r_sum
iphone['Full Review'] = full_sum
iphone
# Out:
#                       Rating            Review Summary  \
# 0                  Brilliant                 Brilliant
# 1           Perfect product!          Perfect product!
# 2              Great product             Great product
# 3          Worth every penny         Worth every penny
# 4                Good choice               Good choice
# 5         Highly recommended        Highly recommended
# 6           Perfect product!          Perfect product!
# 7                  Fabulous!                 Fabulous!
# 8           Perfect product!          Perfect product!
# 9                  Wonderful                 Wonderful
# 10         Worth every penny         Worth every penny
# 11          Perfect product!          Perfect product!
# 12         Worth every penny         Worth every penny
# 13              Nice product              Nice product
# 14            Simply awesome            Simply awesome
# 15                  Terrific                  Terrific
# 16        Highly recommended        Highly recommended
# 17            Classy product            Classy product
# 18                 Wonderful                 Wonderful
# 19                 Brilliant                 Brilliant
# 20                 Must buy!                 Must buy!
# 21         Terrific purchase         Terrific purchase
# 22     Mind-blowing purchase     Mind-blowing purchase
# 23             Great product             Great product
# 24         Terrific purchase         Terrific purchase
# 25            Simply awesome            Simply awesome
# 26      Good quality product      Good quality product
# 27                 Very poor                 Very poor
# 28       Best in the market!       Best in the market!
# 29                 Must buy!                 Must buy!
# ..                       ...                       ...
# 70     Mind-blowing purchase     Mind-blowing purchase
# 71      Good quality product      Good quality product
# 72         Terrific purchase         Terrific purchase
# 73                   Awesome                   Awesome
# 74            Decent product            Decent product
# 75      Good quality product      Good quality product
# 76                 Just wow!                 Just wow!
# 77                 Excellent                 Excellent
# 78                   Awesome                   Awesome
# 79                    Super!                    Super!
# 80                 Excellent                 Excellent
# 81              Does the job              Does the job
# 82                 Wonderful                 Wonderful
# 83      Good quality product      Good quality product
# 84          Perfect product!          Perfect product!
# 85            Classy product            Classy product
# 86            Classy product            Classy product
# 87     Mind-blowing purchase     Mind-blowing purchase
# 88                    Super!                    Super!
# 89           Value-for-money           Value-for-money
# 90                 Brilliant                 Brilliant
# 91  Most Price worthy Iphone  Most Price worthy Iphone
# 92    Not recommended at all    Not recommended at all
# 93       Best in the market!       Best in the market!
# 94         Terrific purchase         Terrific purchase
# 95                 Excellent                 Excellent
# 96                 Fabulous!                 Fabulous!
# 97                 Wonderful                 Wonderful
# 98                 Fabulous!                 Fabulous!
# 99           Value-for-money           Value-for-money
#
#                                           Full Review
# 0   The Best Phone for the Money\n\nThe iPhone 11 ...
# 1   Amazing phone with great cameras and better ba...
# 2   Amazing Powerful and Durable Gadget.\n\nI’m am...
# 3   Previously I was using one plus 3t it was a gr...
# 4   So far it’s been an AMAZING experience coming ...
# 5   iphone 11 is a very good phone to buy only if ...
# 6   It’s a must buy who is looking for an upgrade ...
# 7   This is my first iOS phone. I am very happy wi...
# 8   Value for money❤️❤️\nIts awesome mobile phone ...
# 9   *Review after 10 months of usage*\nDoesn't see...
# 10  Best budget Iphone till date ❤️ go for it guys...
# 11  Iphone is just awesome.. battery backup is ver...
# 12  It’s been almost a month since I have been usi...
# 13  Awesome Phone. Slightly high price but worth. ...
# 14  Excellent camera, good performance, no lag. Th...
# 15  Really worth of money. i just love it. It is t...
# 16  It's my first time to use iOS phone and I am l...
# 17  Superb Product !!!\nA big and worthy upgrade f...
# 18  This is my first ever I phone. Before this I w...
# 19  I have migrated from OP 7pro... and trust me, ...
# 20  It’s an amazing product from apple and the cam...
# 21  Upgraded from iphone 6 to 11 best phone for ip...
# 22  This will help you more. See if you are planni...
# 23  Well you all know the specifications . One of ...
# 24  The built quality is not very premium.\nThe ba...
# 25  Really good actually this is my first apple pr...
# 26  it is very good at performance. Camera is best...
# 27  Reviewing again after 5 months. At the beginni...
# 28  Great iPhone very snappy experience as apple k...
# 29  Best Apple iPhone that i have bought at a very...
# ..                                                ...
# 70  Absolutely powerful gadget. Loved it’s look! S...
# 71  I was torn between the oneplus 8 pro and the i...
# 72  I use a Note10+ and have been using both iOS a...
# 73  The phone is completely good\nAs far as camera...
# 74  Everything u ll like it when u use this iPhone...
# 75  I'm switching this phone to oppo reno 10x zoom...
# 76  The ultimate performance\nCamera is superb\nTh...
# 77  Seller - SuperComNet ( my trust in you has gro...
# 78  Can’t beat the software and hardware integrati...
# 79  It's a great phone. From camera to display eve...
# 80  Value for money product. This iphone 11 is rea...
# 81  phone is good but in display is 720p lcd in th...
# 82  I genuinely liked it. One of the best mobile p...
# 83  Awesome camera, smooth and fast UI, display is...
# 84  Worth the money’ starting first from its perfo...
# 85  I write this review after using a week this iP...
# 86  We are on apple ecosystem for almost eight yea...
# 87  i was confused between 11 and 11 pro. i was go...
# 88  This is my first ever iPhone.\nAnd I truly don...
# 89  Just got this iphone 11\nAnd it is most powerf...
# 90  Wow wow and wow, in 48k you will not get anyth...
# 91  Reviewing within 1st Month\n\n\n1st Month Revi...
# 92  They are selling cheep quality items. There is...
# 93  The best all rounder iphone. Flipkart is doing...
# 94  Well , as we all know if its not an Iphone , i...
# 95  A perfect phone and a good battery super camer...
# 96  Everything is perfect pictures come out so cle...
# 97  Nice value for money good and best price I pho...
# 98  Just an awesome phone...upgraded from 6s to 11...
# 99  As usual a great product from Apple. but the l...
#
# [100 rows x 3 columns]

# %% [markdown]
# # Scrape data for first 100 sneakers you find when you visit flipkart.com and search for “sneakers” in the search field.

# %%
driver.get('https://www.flipkart.com')

# %%
# searching product

inp = input("Enter the product: ")
search = driver.find_element_by_xpath("//div[@class='_3OO5Xc']/input")
search.clear()
search.send_keys(inp)

search_btn = driver.find_element_by_xpath("//button[@class='L0Z3Pu']")
search_btn.click()
# Out:
# Enter the product: Sneakers

# %%
brand = []
p_desc = []
price = []
discount = []
url_list = []

# %%
temp = driver.find_elements_by_xpath("//nav[@class='yFHi8N']/a")
for i in temp:
    url_list.append(i.get_attribute('href'))

# %%
for i in range(3):
    driver.get(url_list[i])
    for m in driver.find_elements_by_xpath("//div[@class='_2WkVRV']"):
        if len(brand) == 100:
            break
        else:
            brand.append(m.text)
    
    for j in driver.find_elements_by_xpath("//a[@class='IRpwTa']"):
        if len(p_desc) == 100:
            break
        else:
            p_desc.append(j.text)
    
    for k in driver.find_elements_by_xpath("//div[@class='_30jeq3']"):
        if len(price) == 100:
            break
        else:
            price.append(k.text)
    
    for l in driver.find_elements_by_xpath("//div[@class='_3Ay6Sb']/span"):
        if len(discount) == 100:
            break
        else:
            discount.append(l.text)

# %%
sneakers = pd.DataFrame({})
sneakers['Brand'] = brand
sneakers['Description'] = p_desc
sneakers['Price'] = price
sneakers['Discount'] = discount

# %%
print(len(brand), len(p_desc), len(price), len(discount))
# Out:
# 100 100 100 100

# %% [markdown]
# # Go to the link - https://www.myntra.com/shoes
# # Set Price filter to “Rs. 6649 to Rs. 13099” , Color filter to “Black”, as shown in the below image
# # And then scrape First 100 shoes data you get. The data should include “Brand” of the shoes , Short Shoe description, price of the shoe

# %%
driver.get('https://www.myntra.com/shoes')

# %%
driver.find_element_by_xpath('//*[@id="mountRoot"]/div/div[1]/main/div[3]/div[1]/section/div/div[6]/ul/li[1]/label').click()

# %%
driver.find_element_by_xpath("//*[@id='mountRoot']/div/div[1]/main/div[3]/div[1]/section/div/div[5]/ul/li[2]/label").click()

# %%
brand = []
s_desc = []
price = []
url_list1 = []

# %%
abc = driver.find_elements_by_xpath("//li[@class='pagination-number']/a")
for i in abc:
    url_list1.append(i.get_attribute('href'))

# %%
url_list1
# Out:
# ['https://www.myntra.com/shoes?f=Color%3ABlack_36454f&plaEnabled=false&rf=Price%3A6657.0_13105.0_6657.0%20TO%2013105.0&p=2',
#  'https://www.myntra.com/shoes?f=Color%3ABlack_36454f&plaEnabled=false&rf=Price%3A6657.0_13105.0_6657.0%20TO%2013105.0&p=3',
#  'https://www.myntra.com/shoes?f=Color%3ABlack_36454f&plaEnabled=false&rf=Price%3A6657.0_13105.0_6657.0%20TO%2013105.0&p=4',
#  'https://www.myntra.com/shoes?f=Color%3ABlack_36454f&plaEnabled=false&rf=Price%3A6657.0_13105.0_6657.0%20TO%2013105.0&p=5',
#  'https://www.myntra.com/shoes?f=Color%3ABlack_36454f&plaEnabled=false&rf=Price%3A6657.0_13105.0_6657.0%20TO%2013105.0&p=6',
#  'https://www.myntra.com/shoes?f=Color%3ABlack_36454f&plaEnabled=false&rf=Price%3A6657.0_13105.0_6657.0%20TO%2013105.0&p=7',
#  'https://www.myntra.com/shoes?f=Color%3ABlack_36454f&plaEnabled=false&rf=Price%3A6657.0_13105.0_6657.0%20TO%2013105.0&p=8',
#  'https://www.myntra.com/shoes?f=Color%3ABlack_36454f&plaEnabled=false&rf=Price%3A6657.0_13105.0_6657.0%20TO%2013105.0&p=9',
#  'https://www.myntra.com/shoes?f=Color%3ABlack_36454f&plaEnabled=false&rf=Price%3A6657.0_13105.0_6657.0%20TO%2013105.0&p=10']

# %%
for i in range(0,2):
    for j in driver.find_elements_by_xpath('//h3[@class="product-brand"]'):
        if len(brand) == 100:
            break
        else:
            brand.append(j.text)
    
    for k in driver.find_elements_by_xpath('//div[@class="product-price"]'):
        if len(price) == 100:
            break
        else:
            price.append(k.text)
    
    for l in driver.find_elements_by_xpath('//h4[@class="product-product"]'):
        if len(s_desc) == 100:
            break
        else:
            s_desc.append(l.text)
    
    driver.get(url_list1[i])

# %%
print(len(brand), len(s_desc), len(price))
# Out:
# 100 100 100

# %%
shoes = pd.DataFrame({})
shoes['Brand'] = brand
shoes['Description'] = s_desc
shoes['Price'] = price
shoes
# Out:
#                    Brand                        Description  \
# 0        PUMA Motorsport      Unisex Mercedes Running Shoes
# 1                   Nike       Men KD13 EP Basketball Shoes
# 2                   Nike       Women AIR ZOOM Running Shoes
# 3                   Nike        Men JORDAN DELTA Basketball
# 4                   Nike         Men React Infinity Running
# 5                   Nike     Women PEGASUS 37 Running Shoes
# 6                   Nike         Men AIR ZOOM Running Shoes
# 7                   Nike          Women REACT Running Shoes
# 8                   Nike     AIR ZOOM PEGASUS Running Shoes
# 9                   Nike          Men JOYRIDE Running Shoes
# 10                  Nike       Women AIR ZOOM Running Shoes
# 11                  Nike             Women AIR ZOOM Running
# 12          UNDER ARMOUR      Charged Rogue 2 Wide 2E Shoes
# 13          UNDER ARMOUR         HOVR Sonic 3 Running Shoes
# 14                  Puma         Men Velocity Nitro Running
# 15          UNDER ARMOUR          Men Liquify Running Shoes
# 16                  Nike          Men JORDAN DELTA Sneakers
# 17                  Puma        Men UltraRide Running Shoes
# 18          UNDER ARMOUR     Women TriBase Reign 2 Training
# 19                  Puma         Unisex Futurverse Sneakers
# 20              Skechers      Men VIPER COMPETITOR Training
# 21          UNDER ARMOUR        Men HOVR Strt Walking Shoes
# 22          Hush Puppies  Men Solid Leather Formal Slip-Ons
# 23          UNDER ARMOUR      Unisex SC 3ZER0 IV Basketball
# 24                  Puma     Men FUTURE Z 3.1Football Shoes
# 25          UNDER ARMOUR         Women Charged Breathe TR 2
# 26          UNDER ARMOUR         HOVR Sonic 3 Running Shoes
# 27          UNDER ARMOUR      Charged Impulse Running Shoes
# 28        Onitsuka Tiger            Unisex Big Logo Trainer
# 29             Cole Haan                   Leather Sneakers
# ..                   ...                                ...
# 70             Cole Haan               Women Open Toe Flats
# 71  Heel & Buckle London         Men Leather Formal Oxfords
# 72  Heel & Buckle London                Women Leather Pumps
# 73             Cole Haan     Women Solid Leather Ballerinas
# 74             Cole Haan                      Women Sandals
# 75          UNDER ARMOUR     Men HOVR Rise 2 Training Shoes
# 76             Cole Haan        Women Woven Design Sneakers
# 77          UNDER ARMOUR       Men Charged Bandit 6 Running
# 78                  Nike          Men REACT MILER 2 Running
# 79                ADIDAS      Men Ultraboost DNA CC_1 Shoes
# 80          UNDER ARMOUR     Charged RC Sportstyle Sneakers
# 81          UNDER ARMOUR      Women Charged Breathe OIL SLK
# 82                 Ruosh  Men Solid Leather Formal Slip-Ons
# 83          UNDER ARMOUR          Charged Pursuit 2 Running
# 84                Reebok         Men Nano X1 Training Shoes
# 85                 Ruosh     Men Solid Leather Formal Monks
# 86                  ALDO               Women Open Toe Flats
# 87                 Ruosh    Men Solid Leather Formal Derbys
# 88                Reebok     Unisex Zig Kinetica II Running
# 89                  Puma                 Men Football Shoes
# 90          UNDER ARMOUR      Charged Rogue 2 Running Shoes
# 91                  Puma        Men UltraRide Running Shoes
# 92                  Nike          Men REACT MILER 2 Running
# 93             Florsheim   Men Solid Leather Formal Loafers
# 94               Saint G               Leather Heeled Boots
# 95                  Puma      Men Ignite Sock Plus Sneakers
# 96          Kenneth Cole             Women Solid Flat Boots
# 97                ADIDAS        Men Supernova Running Shoes
# 98             Florsheim    Men Solid Leather Formal Derbys
# 99                  ALDO               Women Black Sneakers
#
#                           Price
# 0                      Rs. 7999
# 1                     Rs. 12995
# 2    Rs. 7721Rs. 10295(25% OFF)
# 3                     Rs. 12495
# 4   Rs. 10846Rs. 15495(30% OFF)
# 5     Rs. 7496Rs. 9995(25% OFF)
# 6    Rs. 7206Rs. 10295(30% OFF)
# 7    Rs. 8396Rs. 11995(30% OFF)
# 8                     Rs. 11495
# 9   Rs. 10496Rs. 14995(30% OFF)
# 10  Rs. 6996Rs. 9995( 30 % OFF)
# 11  Rs. 10121Rs. 13495(25% OFF)
# 12                     Rs. 7999
# 13                    Rs. 10999
# 14                    Rs. 10999
# 15                    Rs. 10999
# 16                    Rs. 10995
# 17    Rs. 7199Rs. 8999(20% OFF)
# 18                    Rs. 11999
# 19                     Rs. 9999
# 20                     Rs. 6999
# 21                     Rs. 9999
# 22                     Rs. 8999
# 23                     Rs. 8999
# 24    Rs. 6799Rs. 7999(15% OFF)
# 25                     Rs. 7999
# 26                    Rs. 10999
# 27                     Rs. 7999
# 28                    Rs. 10999
# 29                    Rs. 10999
# ..                          ...
# 70   Rs. 8999Rs. 11999(25% OFF)
# 71   Rs. 7693Rs. 10990(30% OFF)
# 72    Rs. 7192Rs. 8990(20% OFF)
# 73  Rs. 10499Rs. 13999(25% OFF)
# 74   Rs. 6749Rs. 14999(55% OFF)
# 75                     Rs. 9999
# 76   Rs. 6749Rs. 14999(55% OFF)
# 77    Rs. 7199Rs. 8999(20% OFF)
# 78   Rs. 9196Rs. 11495(20% OFF)
# 79  Rs. 12749Rs. 16999(25% OFF)
# 80                     Rs. 8999
# 81                     Rs. 8999
# 82                     Rs. 6990
# 83                     Rs. 6999
# 84    Rs. 6999Rs. 9999(30% OFF)
# 85                     Rs. 6990
# 86                     Rs. 8999
# 87                     Rs. 8990
# 88                     Rs. 9999
# 89  Rs. 12749Rs. 16999(25% OFF)
# 90                     Rs. 7999
# 91    Rs. 7199Rs. 8999(20% OFF)
# 92   Rs. 9770Rs. 11495(15% OFF)
# 93                     Rs. 6995
# 94                    Rs. 11800
# 95    Rs. 6749Rs. 8999(25% OFF)
# 96   Rs. 9513Rs. 13590(30% OFF)
# 97    Rs. 7999Rs. 9999(20% OFF)
# 98                     Rs. 6995
# 99                     Rs. 8999
#
# [100 rows x 3 columns]
